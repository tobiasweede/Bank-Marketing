# %% [markdown]
# # Marketing Case Study Analysis

# %%
import pandas as pd

# %%
#read data
data = pd.read_csv('dataset-students.csv', sep=',')

# %%
display(data.head())
data.describe()
# Out:
#    Alter             Beruf Familienstand         Bildung Kreditverpflichtung  \
# 0     56           Service   Verheiratet     Hauptschule                nein
# 1     57  Dienstleistungen   Verheiratet  Hochschulreife           unbekannt
# 2     37  Dienstleistungen   Verheiratet  Hochschulreife                nein
# 3     40        Verwaltung   Verheiratet      Realschule                nein
# 4     56  Dienstleistungen   Verheiratet  Hochschulreife                nein
#
#   Wohnsituation Kredit  Kontakt Monat Wochentag  ...  Kampagne  \
# 0          nein   nein  Telefon   Mai    Montag  ...         1
# 1          nein   nein  Telefon   Mai    Montag  ...         1
# 2            ja   nein  Telefon   Mai    Montag  ...         1
# 3          nein   nein  Telefon   Mai    Montag  ...         1
# 4          nein     ja  Telefon   Mai    Montag  ...         1
#
#    Kontaktversuche  Vorherige Kontaktanzahl  Vorheriges Ergebnis  \
# ...

# %%
data
# Out:
#        Alter             Beruf Familienstand                   Bildung  \
# 0         56           Service   Verheiratet               Hauptschule
# 1         57  Dienstleistungen   Verheiratet            Hochschulreife
# 2         37  Dienstleistungen   Verheiratet            Hochschulreife
# 3         40        Verwaltung   Verheiratet                Realschule
# 4         56  Dienstleistungen   Verheiratet            Hochschulreife
# ...      ...               ...           ...                       ...
# 41183     73            Rentne   Verheiratet  Berufliche Weiterbildung
# 41184     46         Industrie   Verheiratet  Berufliche Weiterbildung
# 41185     56            Rentne   Verheiratet     Universitätsabschluss
# 41186     44           Technik   Verheiratet  Berufliche Weiterbildung
# 41187     74            Rentne   Verheiratet  Berufliche Weiterbildung
#
#       Kreditverpflichtung Wohnsituation Kredit  Kontakt     Monat Wochentag  \
# ...

# %%
# From here you can do whatever you want with the data
# For example:
# Use a random forest classifier from the scikit-learn library
# Or use imbalanced-learn to deal with the class imbalance of the target variable
